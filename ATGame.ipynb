# %%
from selenium import webdriver

import time
import multiprocessing

#크롬 실행 및 사이트 이동
driver = webdriver.Chrome("D:/temp/chromedriver.exe")

#로그인 창 이동
driver.get("http://www.atgame.kr/member/login.atg?login_rtn=")

# %%
from selenium import webdriver

import time
import multiprocessing

flag = False

#크롬 실행 및 사이트 이동
driver = webdriver.Chrome("D:/temp/chromedriver.exe")

#로그인 창 이동
driver.get("http://www.atgame.kr/member/login.atg?login_rtn=")

#로그인
el_User_ID = driver.find_element_by_id("id")
el_User_ID.send_keys("tjsrb7575")
el_User_PW = driver.find_element_by_id("pw")
el_User_PW.send_keys("!awsksg951753")

driver.find_element_by_id("btn-login").click()

#상품 페이지 이동
driver.get('http://www.atgame.kr/product/view.atg?item=1103012988')
#   플스5   'http://www.atgame.kr/product/view.atg?item=1103012988'

#주문페이지 이동
el_div_class = driver.find_element_by_class_name("wrap-btn")
#el = driver.find_element_by_id("btn-order")
text = el_div_class.text
while True:
    if text == '장바구니\n바로구매'  :
        el = driver.find_element_by_id("btn-order")
        el.click()
        break
    else :
        driver.refresh()
        time.sleep(0.05)

from playsound import playsound
#playsound('D:/temp/sister_calling.mp3')

#결제 페이지 처리
el_phone_1 = driver.find_element_by_id("ord_cell")
el_phone_1.send_keys("01099387275")

driver.find_element_by_id("chk-ord").click()

driver.find_element_by_id("rdo-payment-bank").click()

from selenium.webdriver.support.select import Select
select=Select(driver.find_element_by_id("bankcode"))
select.select_by_index(3)

el_name = driver.find_element_by_id("payer")
el_name.send_keys("김선규")

#결제버튼 누르기
el_finish = driver.find_element_by_id("btn-order").click()

# %%
#주문페이지 이동
el_div_class = driver.find_element_by_class_name("wrap-btn")
#el = driver.find_element_by_id("btn-order")
text = el_div_class.text
while True:
    if text == '장바구니\n바로구매'  :
        el = driver.find_element_by_id("btn-order")
        el.click()
        break
    else :
        driver.refresh()
        time.sleep(0.05)

from playsound import playsound
#playsound('D:/temp/sister_calling.mp3')

#결제 페이지 처리
el_phone_1 = driver.find_element_by_id("ord_cell")
el_phone_1.send_keys("01099387275")

driver.find_element_by_id("chk-ord").click()

driver.find_element_by_id("rdo-payment-bank").click()

from selenium.webdriver.support.select import Select
select=Select(driver.find_element_by_id("bankcode"))
select.select_by_index(3)

el_name = driver.find_element_by_id("payer")
el_name.send_keys("김선규")

#결제버튼 누르기
el_finish = driver.find_element_by_id("btn-order").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-2-f0c38b3ee5b4> in <module>
#      16
#      17 #결제 페이지 처리
# ---> 18 el_phone_1 = driver.find_element_by_id("ord_cell")
#      19 el_phone_1.send_keys("01099387275")
#      20
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...
